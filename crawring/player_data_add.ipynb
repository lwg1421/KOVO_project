# %%
import requests
import re
import warnings

# 불필요한 경고 출력을 방지합니다.
warnings.filterwarnings('ignore')

# %%
link_list = ["https://www.kovo.co.kr/team/22002_player_view.asp?s_part=1&p_code=0001940","https://www.kovo.co.kr/team/22002_player_view.asp?s_part=1&p_code=1000176"]

# %%
from bs4 import BeautifulSoup as bs

# %%
player_position = []
player_name = []
player_birth = []
player_height = []
player_weight = []
player_history = []
player_school = []
player_img = []

for player_link in link_list :
    url = player_link
    player_html = requests.get(url, verify = False).text
    player_soup = bs(player_html,"lxml")

    # 선수 포지션
    player_position.append(re.sub("\xa0", "",str(player_soup.select("div.info > p.no")).strip('[<p class="no">'"</p>]")))

    # 선수 이미지 링크
    player_img.append("https://www.kovo.co.kr/"+player_soup.select("div.clearfix > div.img > img")[0].get("src"))

    # 선수 이름
    player_name.append(str(player_soup.select("div.info > p.name")).strip('[<p class="name">'"</p>]"))

    # 선수 생년월일
    player_birth.append(str(player_soup.select("dl.clearfix > dd")[0]).strip("<dd>""</dd>"))

    # 선수 신장
    player_height.append(str(player_soup.select("dl.clearfix > dd")[1]).split("/")[0].strip("<dd>"" "))

    # 선수 몸무게
    player_weight.append(str(player_soup.select("dl.clearfix > dd")[1]).split("/")[1].strip("<"" "))

    # 선수 출신학교
    player_school.append(str(player_soup.select("dl.clearfix > dd")[2]).strip("<dd>""</dd>"))

    # 선수 선수 이력
    player_history.append(re.sub("\xa0", "", player_soup.select("dl.clearfix > dd")[-1].get_text().strip("\n")))

    # 선수 선수 이력 여러개일 경우 split으로 나눠줌
    # re.sub("\xa0", "", player_soup.select("dl.clearfix > dd")[-1].get_text().strip("\n")).split("\n")

# %%
import pandas as pd

# %%
player_df = pd.DataFrame({"player_name":player_name,"player_position":player_position,"player_img":player_img,"player_birth":player_birth,"player_height":player_height,"player_weight":player_weight,"player_school":player_school,"player_history":player_history})

# %%
player_df["player_school"] = "NA"

# %%
player_df
# Out:
#   player_name       player_position  \
# 0         펠리페  NO.2 OPPOSITE SPIKER
# 1        히메네즈  NO.2 OPPOSITE SPIKER
#
#                                           player_img   player_birth  \
# 0  https://www.kovo.co.kr//upfiles/player/0001940...  1988년 06월 12일
# 1  https://www.kovo.co.kr//upfiles/player/1000176...  1990년 01월 09일
#
#   player_height player_weight player_school player_history
# 0         204cm         111kg            NA          현대캐피탈
# 1         200cm          91kg            NA          현대캐피탈

# %%
player_df.loc[2] = ["차영석","NO.1 MIDDLE BLOCKER","https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAxODAyMTZfODYg%2FMDAxNTE4NzY5MDA3NTYw.UdQqc8bQLfo7wmgtFRW9HnmzjdV3bmAQOkjYOuImA3Eg.JXV3QXe8jEf3_vYb5ABgw7kcUZJaCLyZCBR1hndcVyYg.JPEG.jcg8708%2F0001866_1.jpg&type=sc960_832","1994년 04월 17일","193cm","85kg","담양동초-담양중-순천제일고-인하대","2016년 현대캐피탈 스카이워커스 입단"]
player_df.loc[3] = ["김형진","NO.4 SETTER","https://w.namu.la/s/58d9b4c005f6e13ba2a7705806523d5a5465a93ca4ac69c569cbfc7ba60229f959e9aa23dd54ffa8ecfdf0a9bf5d2933fc0c432ebdf20736e59df4d9acc8d3ca40ba7758f2279ece3611bd91c1f53bf9c5c7b5ee5739912135f06813abf58acc","1995년 03월 10일","186cm","78kg","토평초-남성중-남성고-홍익대","2017년 대학배구 세터상 2018년 KOVO컵 라이징 스타상"]

# %%
player_df.to_excel("C:/kovo/player_data_add.xlsx")

# %%
data = pd.read_excel("C:/kovo/player_data.xlsx")
data.head()
# Out:
#   player_name       player_position  \
# 0         김선호   NO.6 OUTSIDE HITTER
# 1         박주형   NO.9 OUTSIDE HITTER
# 2         송준호   NO.8 OUTSIDE HITTER
# 3         오레올  NO.10 OUTSIDE HITTER
# 4         전광인  NO.12 OUTSIDE HITTER
#
#                                           player_img   player_birth  \
# 0  https://www.kovo.co.kr//upfiles/player/1000059...  1999년 01월 18일
# 1  https://www.kovo.co.kr//upfiles/player/0001178...  1987년 08월 05일
# 2  https://www.kovo.co.kr//upfiles/player/0001377...  1991년 06월 05일
# 3  https://www.kovo.co.kr//upfiles/player/0001365...  1986년 07월 22일
# 4  https://www.kovo.co.kr//upfiles/player/0001462...  1991년 09월 18일
#
#   player_height player_weight            player_school  \
# 0         187cm          82kg          부송초-남성중-남성고-한양대
# 1         193cm          79kg  대천초 / 성지중 / 성지공고 / 성균관대
# 2         192cm          83kg          중앙중 / 중앙고 / 홍익대
# 3         207cm         104kg                      NaN
# 4         194cm          88kg       하동초 / 동명중·고 / 성균관대
#
#                                       player_history
# 0      2020-2021 V리그  현대캐피탈드래프트1라운드 1순위 (2020.10.16)
# 1  2010-2011 V리그  우리캐피탈드래프트1라운드 2순위 (2010.11.04)\...
# 2  2012-2013 V리그  현대캐피탈드래프트1라운드 4순위 (2012.10.22)\...
# 3  2012-2013 V리그  LIG손해보험 (2012.10.01)\n2015-2016...
# 4  2013-2014 V리그  한국전력드래프트1라운드 1순위 (2013.09.10)\n...

# %%
player_data_final = data.append(player_df,ignore_index = True)
player_data_final
# Out:
#    player_name        player_position  \
# 0          김선호    NO.6 OUTSIDE HITTER
# 1          박주형    NO.9 OUTSIDE HITTER
# 2          송준호    NO.8 OUTSIDE HITTER
# 3          오레올   NO.10 OUTSIDE HITTER
# 4          전광인   NO.12 OUTSIDE HITTER
# 5          함형진    NO.4 OUTSIDE HITTER
# 6          홍동선   NO.18 OUTSIDE HITTER
# 7          문성민  NO.15 OPPOSITE SPIKER
# 8          최은석  NO.33 OPPOSITE SPIKER
# 9          허수봉   NO.7 OPPOSITE SPIKER
# 10         박상하   NO.17 MIDDLE BLOCKER
# 11         박준혁   NO.23 MIDDLE BLOCKER
# 12         송원근   NO.71 MIDDLE BLOCKER
# 13         정태준   NO.31 MIDDLE BLOCKER
# 8          193cm          75kg              대석초-필미중-제일고-중부대
# 9          195cm          75kg            호연초-경북사대부중-경북사대부고
# 10         197cm          94kg       남천초 / 제천중 / 의림공고 / 경희대
# 11         205cm          88kg         매산초/ 명지중 / 송림고 / 명지대
# 12         197cm          85kg                      수성고-인하대
# 13         198cm          89kg        연포초 / 대연중 / 성지고 / 홍익대
# 14         195cm          85kg            군위초-경북체중-경북체고-홍익대
# 15         195cm          77kg            동인초-각리중-순천제일고-경기대
# 16         189cm          76kg             동인초-옥천중-옥천고-성균관대
# 17         170cm          64kg              하양초-소사중-송산고-인하대
# 18         175cm          72kg        유성초 / 중앙중 / 중앙고 / 홍익대
# 19         170cm          63kg                  가야초-대연중-성지고
# 20         204cm         111kg                           NA
# 21         200cm          91kg                           NA
# 22         193cm          85kg           담양동초-담양중-순천제일고-인하대
# 23         186cm          78kg              토평초-남성중-남성고-홍익대
#
#                                        player_history
# 0       2020-2021 V리그  현대캐피탈드래프트1라운드 1순위 (2020.10.16)
# 1   2010-2011 V리그  우리캐피탈드래프트1라운드 2순위 (2010.11.04)\...
# 2   2012-2013 V리그  현대캐피탈드래프트1라운드 4순위 (2012.10.22)\...
# 3   2012-2013 V리그  LIG손해보험 (2012.10.01)\n2015-2016...
# 4   2013-2014 V리그  한국전력드래프트1라운드 1순위 (2013.09.10)\n...
# 5   2017-2018 V리그  현대캐피탈드래프트2라운드 7순위 (2017.07.01)\...
# 6       2021-2022 V리그  현대캐피탈드래프트1라운드 1순위 (2021.10.06)
# 7   2008-2009 V리그  KEPCO45드래프트1라운드 1순위 (2008.11.04...
# 8   2019-2020 V리그  현대캐피탈드래프트1라운드 7순위 (2019.10.31)\...
# 9   2016-2017 V리그  대한항공드래프트1라운드 3순위 (2016.10.26)\n...
# 10  2008-2009 V리그  드림식스드래프트1라운드 5순위 (2008.11.27)\n...
# 11  2017-2018 V리그  현대캐피탈드래프트2라운드 1순위 (2017.10.12)\...
# 12      2019-2020 V리그  현대캐피탈드래프트2라운드 1순위 (2019.10.31)
# 13      2021-2022 V리그  현대캐피탈드래프트1라운드 2순위 (2021.10.06)
# 14  2011-2012 V리그  현대캐피탈드래프트1라운드 4순위 (2011.10.20)\...
# 15  2019-2020 V리그  한국전력드래프트1라운드 1순위 (2019.09.22)\n...
# 16      2018-2019 V리그  현대캐피탈드래프트1라운드 6순위 (2018.10.19)
# 17      2020-2021 V리그  현대캐피탈드래프트1라운드 4순위 (2020.10.16)
# 18  2005      V리그  삼성화재프로출범등록 (2005.01.23)\n2010-2...
# 19  2020-2021 V리그  현대캐피탈드래프트2라운드 4순위 (2020.10.16)\...
# 20                                              현대캐피탈
# 21                                              현대캐피탈
# 22                              2016년 현대캐피탈 스카이워커스 입단
# 23                 2017년 대학배구 세터상 2018년 KOVO컵 라이징 스타상

# %%
player_data_final.to_excel("C:/kovo/player_data_final.xlsx")
